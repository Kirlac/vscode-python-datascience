# %%
import pandas as pd
import numpy as np
data = pd.read_csv('data.csv')

# %%
data.replace('?', np.nan, inplace=True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %%
data.corr().abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055513
# sibsp     0.027825
# parch     0.082660
# fare      0.244265

# %%
data['relatives'] = data.apply(lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr().abs()[['survived']]
# Out:
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055513
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# relatives  0.201719

# %%
data = data[['sex','pclass','age','relatives','fare','survived']].dropna()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7464114832535885

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
# Out:
# Using TensorFlow backend.

# %%
model.add(Dense(5, kernel_initializer='uniform', activation='relu', input_dim=5))
model.add(Dense(5, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 836/836 [==============================] - 0s 202us/step - loss: 0.6924 - accuracy: 0.5634
# Epoch 2/50
# 836/836 [==============================] - 0s 59us/step - loss: 0.6900 - accuracy: 0.5861
# Epoch 3/50
# 836/836 [==============================] - 0s 61us/step - loss: 0.6857 - accuracy: 0.5861
# Epoch 4/50
# 836/836 [==============================] - 0s 51us/step - loss: 0.6781 - accuracy: 0.5861
# Epoch 5/50
# 836/836 [==============================] - 0s 47us/step - loss: 0.6657 - accuracy: 0.5873
# Epoch 6/50
# 836/836 [==============================] - 0s 49us/step - loss: 0.6477 - accuracy: 0.6400
# Epoch 7/50
# 836/836 [==============================] - 0s 48us/step - loss: 0.6257 - accuracy: 0.7524
# Epoch 8/50
# 836/836 [==============================] - 0s 47us/step - loss: 0.6016 - accuracy: 0.7715
# Epoch 9/50
# 836/836 [==============================] - 0s 48us/step - loss: 0.5774 - accuracy: 0.7751
# Epoch 10/50
# 836/836 [==============================] - 0s 45us/step - loss: 0.5556 - accuracy: 0.7715
# Epoch 11/50
# 836/836 [==============================] - 0s 51us/step - loss: 0.5373 - accuracy: 0.7751
# Epoch 12/50
# 836/836 [==============================] - 0s 48us/step - loss: 0.5215 - accuracy: 0.7739
# Epoch 13/50
# 836/836 [==============================] - 0s 50us/step - loss: 0.5094 - accuracy: 0.7715
# Epoch 14/50
# 836/836 [==============================] - 0s 47us/step - loss: 0.5004 - accuracy: 0.7763
# Epoch 15/50
# 836/836 [==============================] - 0s 45us/step - loss: 0.4931 - accuracy: 0.7763
# Epoch 16/50
# 836/836 [==============================] - 0s 39us/step - loss: 0.4874 - accuracy: 0.7763
# Epoch 17/50
# 836/836 [==============================] - 0s 36us/step - loss: 0.4825 - accuracy: 0.7835
# Epoch 18/50
# 836/836 [==============================] - 0s 38us/step - loss: 0.4781 - accuracy: 0.7799
# Epoch 19/50
